# %% [markdown]
# <a href="https://colab.research.google.com/github/vcnzx/Machine_Learning_Project/blob/main/SPA_Wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Spanish Wine Quality Prediction
# Author: Charlie Ventura

# %% [markdown]
# ##Import Libraries

# %%
## Pandas
import pandas as pd
## Numpy
import numpy as np
## MatPlotLib
import matplotlib.pyplot as plt

# %% [markdown]
# ##Load Data

# %%
fpath = '/content/drive/MyDrive/CodingDojo/02-MachineLearning/Week08/Data/wines_SPA.csv'
df = pd.read_csv(fpath)

# %% [markdown]
# ##Inspect Data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# ...

# %% [markdown]
# ##First choice:
#
# 1. Source of data
# - https://www.kaggle.com/datasets/fedesoriano/spanish-wine-quality-dataset?resource=download
# 2. Brief description of data
# - Data set of spanish red wine.
#
# 3. What is the target?
# - Rating
#
# 4. What does one row represent? (A person? A business? An event? A product?)
# - A product: red wine
# 5. Is this a classification or regression problem?
# - Regression
# 6. How many features does the data have?
# - 10
# 7. How many rows are in the dataset?
# - 7500
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
# - There are a lot of missing values for some of the features
